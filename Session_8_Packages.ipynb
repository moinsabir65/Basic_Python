# %%
# Ramesh is a good students
# he developed a addition code
# its worked very well
# Ramesh later reaslized this addition code No one developed
# Ramesh has very charity
# He decided handover this code to entire world
# he contacted a Anaconda company
# who ever install the anaconda , automatically this should come
# to thier laptop
# Anaconda agreed
# give me that code
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
# Ramesh give a name called addition
# single file
# addition.py
# this single file we called as module
# module name : addition
# languge : python
# we want to use this : import

# %%
import addtion
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-9e0dc846ccf9> in <module>
# ----> 1 import addtion
#
# ModuleNotFoundError: No module named 'addtion'

# %%
import random

# %%
import time

# %%
import cv2

# %%
import random

# %%
random
# Out:
# <module 'random' from 'C:\\Users\\dell\\anaconda3\\lib\\random.py'>

# %%
import cv2

# %%
import wordcloud

# %%
import addition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-d56dff5238cd> in <module>
# ----> 1 import addition
#
# ModuleNotFoundError: No module named 'addition'

# %%
# Module Name : random
import random

# %%
# Module Name : math
import math

# %%
# Module Name : Time 
import time

# %%
# Module Name : cv2 
import cv2

# %%
random
# Out:
# <module 'random' from 'C:\\Users\\dell\\anaconda3\\lib\\random.py'>

# %%
you have a 4 gifts 

addition
sub
mul
div

# %%
# case-1:
import addition
import sub
import mul
import div
# case-2:
import arthematic
dir(arthematic)
# add sub mul div

# %%
# telephone directory

import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_BuiltinMethodType',
#  '_MethodType',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_inst',
#  '_itertools',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
# step-1:
# import <module_name>
# step-2:
# dir(module_name)

# %%
# kid : randint
random randint
random random
# Out:
#   File "<ipython-input-20-fcb70b35a0e9>", line 2
#     random randint
#                  ^
# SyntaxError: invalid syntax

# %%
import random
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x002D0308>>

# %%
# function
# bound method indicates we missed brackets

# %%
# step-1: import modulename
# step-2: dir(modulename)
# step-3: modulename.methodname

# %%
import random
dir(random)
random.virat
# random uncle does not have a kid name with virat
# random module does not have a attribute name with virat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-2d1251eef5e0> in <module>
#       1 import random
#       2 dir(random)
# ----> 3 random.virat
#
# AttributeError: module 'random' has no attribute 'virat'

# %%
random.randintt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-c028da10dc9c> in <module>
# ----> 1 random.randintt
#
# AttributeError: module 'random' has no attribute 'randintt'

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,10)
# Out:
# 3

# %%
# step-1: import modulename
# step-2: dir(modulename)
# step-3: modulename.methodname
# step-4: help(modulename.methodname)

import random
dir(random)
random.randint
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.random
# Out:
# <function Random.random>

# %%
help(random.random)
# Out:
# Help on built-in function random:
#
# random(...) method of random.Random instance
#     random() -> x in the interval [0, 1).

# %%
dir(random.random)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__text_signature__']

# %%
random.random()
# Out:
# 0.36771982545528115

# %%
random.random()
# Out:
# 0.1627940245645496

# %%
# step-1: import module_name
# step-2: dir(module_name)
# step-3: module_name.method_name
# bound method
# functions
# direct answer
# step-4: help(module_name.method_name)
# step-5: apply the use case

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_BuiltinMethodType',
#  '_MethodType',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_inst',
#  '_itertools',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x002D0308>>

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,20)
# Out:
# 18

# %% [markdown]
# ### Module

# %% [markdown]
# - Module is single python file
#
#     - It contain
#         - Method
#         - Function
#         - Variable
#         - Classes (Oops Concept)

# %% [markdown]
# ## Packages

# %% [markdown]
# - Packages is collection of modules
# - Collection of python files

# %% [markdown]
# ## Analogy

# %% [markdown]
# - Assume that module os one gift
# - Package is  a bag coolection is gift

# %% [markdown]
# ## Methos VS Fuction

# %% [markdown]
# - Method and Function both are defined for some task with some name
#
# - But Method defined under one class
#
# - Function is defined outside the class

# %% [markdown]
# ## Two Errors

# %% [markdown]
# - Module not foud error
#     - Means it is not intalled in out laptop
#
# - Attribute Errot
#
#     - we know that module has function method and variables
#
#     - that are not aailable unter this module
# - Whenever we see that attribute error perform dit on module name

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_BuiltinMethodType',
#  '_MethodType',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_inst',
#  '_itertools',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
import random
# if you use the tab we can avoid dir

# %%
random.random()
# if we observe the function or method: we can use brackets
# take your cursor inside the bracket and apply : shift+tab
# then we can avoid help
# Out:
# 0.3496725847937068

# %%
[0,1]     #   0 and 1 both include
(0.1)     #   0 and 1 both exlude
[0,1)     #   0 include and 1 include
[0,1]     #   0 include  and  1 exclude

# %%
import random
random.randint(10,20)
# Out:
# 14

# %%
# modulename        method name
# random            randint
# random            random
# random            choice   ( inside provide the list of values )
# random            shuffle  ( inside provide the list of values )

# math              pi
# math              e
# math              pow
# math              sin

# time              sleep

# os                getcwd
# os                makedir

# keyword           kwlist

# string            ascii upper
# string            ascii lower
# string            punctuations

# %% [markdown]
# ## All Example Module_Name and Method_Name

# %%
import random
random.randint(10,20)
# Out:
# 17

# %%
import random
random.random()
# Out:
# 0.5947721324006134

# %%
import random
random.choice([1,2,3,4,5])
# Out:
# 1

# %%
l=[10,15,2,5,98]
random.shuffle(l)
l
# Out:
# [98, 10, 5, 15, 2]

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
import math
math.e
# Out:
# 2.718281828459045

# %%
import math
math.pow(2,3)
# Out:
# 8.0

# %%
import math
math.sin(90)
# Out:
# 0.8939966636005579

# %%
import time
time.sleep(5)
print('Hello Moin sabir')
# Out:
# Hello Moin sabir

# %% [markdown]
# ## OS

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Documents\\Data Science\\Python_Session'

# %%
import os
os.mkdir('Moin folder')

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
import string
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
import string
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
import string
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
