# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
# Out:
#   File "<ipython-input-5-ea8edae8d9a3>", line 2
#     pip intall time
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# import time
# time.sleep(5)
# print('Good morning')

# %% [markdown]
# import time
# pip intall time

# %%
moin 100import time
time.sleep(5)
print("goodlmo")
# Out:
#   File "<ipython-input-8-1a11ecb50edc>", line 1
#     moin 100import time
#            ^
# SyntaxError: invalid syntax

# %%
moin=19
moin
# Out:
# 19

# %%
n1=10  # he is about this run cell
n1
# Out:
# 10

# %%
n2=20
n2
# Out:
# 20

# %%
n3=30
n3
# Out:
# 30

# %%
n4=40
n4
# Out:
# 40

# %%
# Code cell indicates square bracket before cell
# if the square is empty means the cell did not run
# when we run the cell, there is number available in square bracke

# %%
print('good morning')
# Out:
# good morning

# %%
import time
time.sleep(5)
print('good morning')
# Out:
# good morning

# %%
# kernel is white color : idle state
# kernel is black color : busy state
# kernel is red color : dead state
# when kernel is busy there is [*] mark appear in square bracketsm

# %% [markdown]
# # Python

# %% [markdown]
# ## Python

# %% [markdown]
# ### Python

# %% [markdown]
# #### python

# %% [markdown]
# ##### pyton

# %% [markdown]
# ###### Python

# %%
- My Name Is Moin Sabir
# Out:
#   File "<ipython-input-25-5bb373c82cda>", line 1
#     - My Name Is Moin Sabir
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# - My Name I Moin Sabir
#
# - I am from saharanpur
#
# - I am pagal

# %%
# kernel is white color : idle state
# kernel is black color : busy state
# kernel is red color : dead state
# when kernel is busy there is [*] mark appear in square brackets

# %% [markdown]
# <img src="https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSEDaMEoX0Tkzqw74YSBab3HI2czZ14hUpGxq1Wuko5h6hGPVhF" class="sFlh5c FyHeAf" alt="9 BEST Websites to Find Free Travel Images" jsname="JuXqh" style="max-width: 2000px; height: 202px; margin: 0px; width: 303px;">
