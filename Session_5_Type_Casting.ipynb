# %% [markdown]
# ## Type Cast

# %% [markdown]
# - Type cast means convert one data type to another data type
#
# - like integer to other data type vice versa

# %%
10+20
# Out:
# 30

# %%
'10'+'20'
# Out:
# '1020'

# %% [markdown]
# **Int to other data types**
#
# - int to float
#
# - int to str
#
# - int to bool

# %%
# portal link
# share your link using google form
# adming madam already shared
# please check whatsapp and email

# %%
n1=100
type(n1)
# Out:
# int

# %%
float_n1=float(n1)
type(float_n1),float_n1
# Out:
# (float, 100.0)

# %%
str_n1=str(n1)
type(str_n1),str_n1
# Out:
# (str, '100')

# %%
bool_n1=bool(n1)
type(bool_n1),bool_n1
# Out:
# (bool, True)

# %%
float(n1)
str(n1)
bool(n1)

# %%
float = decimal
str   = quotes
bool  = True/False

# %%
float(-100),str(-100),bool(-100)
# Out:
# (-100.0, '-100', True)

# %%
float(0),str(0),bool(0)
# Out:
# (0.0, '0', False)

# %% [markdown]
# ### Float to other Data Types

# %%
str(10.5),int(10.5),bool(10.5)
# Out:
# ('10.5', 10, True)

# %%
a=10
b=20
a
b
# Out:
# 20

# %% [markdown]
# ### String to other Data Types

# %%
int('10'),float('20'),bool('30')
# Out:
# (10, 20.0, True)

# %%
int('100.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-2196643303f4> in <module>
# ----> 1 int('100.5')
#
# ValueError: invalid literal for int() with base 10: '100.5'

# %%
int(10.5)    # work
int('10')    # work
int('10.5')  # work
# Out:
# 10

# %%
float(10)       # workgl
float(10.5)     # work
float('10.5')   # work
# Out:
# 10.5

# %%
int('Apple')    # Fail
float('Apple')  # Fail
bool('Apple')   # Work

# %%
int('0'),float('0'),str('0'),bool('')
# Out:
# (0, 0.0, '0', False)

# %%
len('Apple')
# Out:
# 5

# %%
len('0')
# Out:
# 1

# %%
len('')
# Out:
# 0

# %%
float(10) # 10.0
str(10) # '10'
bool(10) # T
bool(0) # F
bool(-100) # T
# Out:
# True

# %%
int(100.5) # 100
str(100.5) # '100.5'
bool(100.5) # T
bool(0.0) # F

# %%
int('10') # 10 Out[44]: In [46]: In [48]: In [50]: Out[50]: In [58]: Out[58]: In [52]: Out[52]: In [54]: Out[54]: In [56]: Out[56]: In [ ]:
float('10') # 10.0
bool('10') # T

# %%
int('10.5') # E
float('10.5') # 10.5
bool('10.5') # T

# %%
bool('0') # T
bool('') # F
bool('apple') # T
int('apple') # E
float('apple') # E

# %%
bool(100) # T
bool('100') # T
bool(100.5) # T
bool('') # F
bool('0') # T

# %% [markdown]
# ### Boolean to other Data Types

# %%
int(True) # 1
float(True) # 1.0
str(True) # 'True'
int(False) # 0
float(False) # 0.0
str(False) # 'False'
# Out:
# 'False'
