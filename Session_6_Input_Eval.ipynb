# %%
number1=100     # hard code values
number2=200     # hard code values
number1+number2

# %%
name='nareshit'
age=25
city='hydrabad'

# %% [markdown]
# **Input**

# %%
input

# %% [markdown]
# - Function
#
# - Bound Method

# %%
import os
os.getcwd

# %%
input()

# %%
a=10

# %%
input()

# %%
input('Enter Your Name')

# %%
input('Enter age')

# %%
input('What is Your Name')

# %%
input()
input()
input()

# %%
name=input('Enter your name')
age=input('Enter your age')
city=input('Enter your city')
print(name)
print(age)
print(city)

# %%
name='moin'
age=20
city='hydrabad'

# %%
n1=input('enter your number1')    # 20
n2=input('enter your number2')    # 30
n1+n2

# %%
# n1=input('enter a number1:') # '20'
# n2=input('enter a number2:') # '30'
# n1+n2 # '20'+'30'='2030'
# n1=int('20')
# n2=int('30')
# n1+n2

#  int me convert kiya hai

n1=int(input('enter your number 1:'))   # 25
n2=int(input('enter your number 2:'))   # 35
n1+n2

# %%
int(input( # wrong approach
int(input("")) # correct approach

# %%
"hyderabda"
"hyderbad' # error
"

# %%
n1=int(input('enter the n1:')) # int('100') = 100
n2=int(input('enter the n2:')) # int('200.5') = error
n1+n2

# %%
n1=int(input('enter your number 1:'))   # 100
n2=float(input('enter your number 2:')) # 200.5
n1+n2

# %%
n1=int(input('enter your number 1:'))   # 100
n2=float(input('enter your number 2:')) # 200
n1+n2

# expected ans: 100+200=300
# what above code is = 300.0
# Out:
# enter your number 1:100
# enter your number 2:200
# 300.0

# %%
n1=int(input('enter the n1:'))
n2=int(input('enter the n2:'))
n1+n2
###############################################
# Drawback-1 : float
n1=int(input('enter the n1:')) # 100
n2=int(input('enter the n2:')) # 100.5 error
n1+n2
# change
n1=int(input('enter the n1:'))
n2=float(input('enter the n2:'))
n1+n2
#######################################################
# Draw back-2:
n1=int(input('enter the n1:')) # 100
n2=float(input('enter the n2:')) # 200
n1+n2 # 300.0

# %% [markdown]
# ## Eval

# %%
int('10')
# Out:
# 10

# %%
int('10.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-6cc59efdcec3> in <module>
# ----> 1 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
float('10')
# Out:
# 10.0

# %%
float('10.5')
# Out:
# 10.5

# %%
int('10')     # work
int('10.5')   # fail
float('10')   # work
float('10.5')  # work

# %%
eval('10')
# Out:
# 10

# %%
eval('10.5')
# Out:
# 10.5

# %%
n1=eval(input('enter your number 1:'))   # 100.5
n2=eval(input('enter your number 2:'))   # 100.5
n1+n2
# Out:
# enter your number 1:100.5
# enter your number 2:100.5
# 201.0

# %%
int('10.5') # fail
int(10.5) # work
round('10.5') # fail
round(10.5) # works

# %%
n=10.5
n1=input()

n,n1
# Out:
# 10.5
# (10.5, '10.5')

# %%
n1=eval(input('enter your number 1:'))    # eval('12') 12
n2=eval(input('enter your number 2:'))    #  eval('13.0') 13.0
n3=n1+n2   # 12+13.0=25.0
int(n3)
# Out:
# enter your number 1:12
# enter your number 2:13.0
# 25

# %%
# wap ask the user enter 3 numbers
# find the avg
# ask the user means: input and keyboard

n1=10
n2=20
n3=30
avg=(n1+n2+n3)/3
avg
# Out:
# 20.0

# %%
eval('13.0')  # 13.0
# which number you entered that value will come
# Out:
# 13.0

# %%
eval('13')
# Out:
# 13

# %%
n1=eval(input("Enter no.1"))
n2=eval(input("Enter no.2"))
n3=eval(input("Enter no.3"))
avg= (n1+n2+n3)/3
print(avg)
Enter no.1 13.0
Enter no.2 25.3
Enter no.3 45.5
# Out:
# Enter no.113.0
# Enter no.225.3
# Enter no.345.5
# 27.933333333333334

# %%
n1=eval(input('enter the n1:'))
n2=eval(input('enter the n2:'))
n3=eval(input('enter the n3:'))
avg=(n1+n2+n3)/3
round(avg,4)
# Out:
# enter the n1:12.3
# enter the n2:13.4
# enter the n3:11.5
# 12.4

# %%
n1=eval(input('enter the n1:'))
n2=eval(input('enter the n2:'))
n3=eval(input('enter the n3:'))
avg=(n1+n2+n3)/3
round(avg,3)
# Out:
# enter the n1:12.4
# enter the n2:11.6
# enter the n3:16.22
# 13.407

# %%
n1=eval(input('enter the n1:'))
n2=eval(input('enter the n2:'))
n3=eval(input('enter the n3:'))
avg=(n1+n2+n3)/3
round(avg,2)
# Out:
# enter the n1:32.2
# enter the n2:11.2
# enter the n3:13.4
# 18.93

# %%
############ Implement all these below qns using Input and eval#################
# wap ask the user calculate area of traingle
# pi=3.14
# radius=20
# area=pi*radius*radius
#wap calculate the area of right angle traingle
# area=0.5*breadth*height
#wap ask the user calcuate area of rectangle
# area= length*breadth
# wap ask the user take two variables
# bill amount
# tip amount
# calculate total bill
# wap ask the user calculate tax amount
# take two variable
# salary
# tax percentage
# tax=salary*tax_percentage/100
