# %% [markdown]
# ## Print Statement

# %% [markdown]
# - Why will use Print Statement
#
#     - Print statement are used for only to see the output
#
#     - If we dont print means its not error
#
#     - We are just not able to see or check the answer

# %%
number1=100
print(number1)
# Out:
# 100

# %%
impor os 
os virat
# Out:
#   File "<ipython-input-8-8e43c8bdcb5b>", line 1
#     impor os
#            ^
# SyntaxError: invalid syntax

# %%
n1=100
n2=200
print(n1,n2)
# Out:
# 100 200

# %%
print(100)
print(100,200)
print(100,200,300)
print(100,200,300,'Apple')
print(n1,n2,300)
print('n1','n2',300)
print('n1',n1,'n2',n2,'Apple')
# Out:
# 100
# 100 200
# 100 200 300
# 100 200 300 Apple
# 100 200 300
# n1 n2 300
# n1 100 n2 200 Apple

# %%
print('n1=',n1,'n2=',n2)
# Out:
# n1= 100 n2= 200

# %%
print('n1=',n1,'and','n2=',n2)
# Out:
# n1= 100 and n2= 200

# %%
n1=100
n2=200
add=n1+n2

# # the addition of n1 and n2 is add
# the addition of 100 and 200 is 300
# fix your print statement

print('the addition of n1 and n2 is add')
print('the addition of 100 and 200 is 300')
print('the addition',n1,'and',n2,'is',add)
# Out:
# the addition of n1 and n2 is add
# the addition of 100 and 200 is 300
# the addition 100 and 200 is 300

# %%
round(1.5),round(2.5),round(3.5),round(4.5)

# 1 or 2 2 or 3 3 or 4 4 or 5
# 2 2 4 4
# half even
# Out:
# (2, 2, 4, 4)

# %%
name='python'
age=25
city='hydrabad'
print('my name is python i am 20 years old i came from hydrabad')
print('my name is name i am age years old i came from city')
print('my name is',name,'i am',age,'years old','i came from',city)
# Out:
# my name is python i am 20 years old i came from hydrabad
# my name is name i am age years old i came from city
# my name is python i am 25 years old i came from hydrabad

# %% [markdown]
# ### Format

# %%
n1=100
n2=200
add=n1+n2

print('the addition is 100 and 200 is 300')
print('the addition is {} and {} is {}')
print('the addition is {} and {} is {}'.format(n1,n2,add))
# Out:
# the addition is 100 and 200 is 300
# the addition is {} and {} is {}
# the addition is 100 and 200 is 300

# %%
format
# Out:
# <function format(value, format_spec='', /)>

# %%
format()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-3a7138326c4d> in <module>
# ----> 1 format()
#
# TypeError: format() takes at least 1 argument (0 given)

# %% [markdown]
# ### Mistake

# %%
print('the addition)
print('')
print('')

# %%
print('the addition of {} and {} is {}',format(n1,n2,add))

# %%
name='python'
age=10
city='hyd'
print('my name is python,Im 10 years old and I came from hyd')
print('my name is {},Im {} years old and I came from {}')
print('my name is {},Im {} years old and I came from {}'.format(name,age,city))
print('my name is {},Im {} years old and I came from {}'.format(city,age,name))
# Out:
# my name is python,Im 10 years old and I came from hyd
# my name is {},Im {} years old and I came from {}
# my name is python,Im 10 years old and I came from hyd
# my name is hyd,Im 10 years old and I came from python

# %% [markdown]
# # f string

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')
print('the addition of {} and {} is {}')
print('the addition of {n1} and {n2} is {add}')
print(f'the addition of {n1} and {n2} is {add}')
# Out:
# the addition of 100 and 200 is 300
# the addition of {} and {} is {}
# the addition of {n1} and {n2} is {add}
# the addition of 100 and 200 is 300

# %%
name='python'
age=10
city='hyd'
print('my name is python,Im 10 years old and I came from hyd')
print('my name is',name,', Im',age,'years old and i came from',city)
print('my name is {} Im {} years old and i came from{}'.format(name,age,city))
print(f'my name is {name},Im {age} years old and I came from {city}')
# Out:
# my name is python,Im 10 years old and I came from hyd
# my name is python , Im 10 years old and i came from hyd
# my name is python Im 10 years old and i came fromhyd
# my name is python,Im 10 years old and I came from hyd

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100+200 is 300')
print('the addition of {}+{} is {}'.format(n1,n2,add))
print(f'the addition of {n1}+{n2} is {add}')
# Out:
# the addition of 100+200 is 300
# the addition of 100+200 is 300
# the addition of 100+200 is 300

# %%
#5x7=35
n1=5

# %%
f"{n1}x{n2}={n1*n2}"
# Out:
# '5x200=1000'

# %%
print('hai')
print('hello')
# Out:
# hai
# hello

# %%
print('hai hello')
# Out:
# hai hello

# %%
print(3)
print(4)
print(5)
# 3 4 5
# Out:
# 3
# 4
# 5

# %% [markdown]
# ### End

# %% [markdown]
# - Multiple print statement attached together

# %%
print(3,end='4')
# Out:
# 34

# %%
print(3,end='=4')
# Out:
# 3=4

# %%
print(3,end='===4')
# Out:
# 3===4

# %%
print(3,end='===>>4')
# Out:
# 3===>>4

# %%
print(3,end='***4')
# Out:
# 3***4

# %%
print(3,'--->',4,'--->5')
# Out:
# 3 ---> 4 --->5

# %%
print(3,end='===>')
print(4,end='***')
print(5)
# Out:
# 3===>4***5

# %%
print(2,'----',3,'-----5')
# Out:
# 2 ---- 3 -----5

# %% [markdown]
# ### Sep

# %%
print(2,3,4,sep='*****')
# Out:
# 2*****3*****4
