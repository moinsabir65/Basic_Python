# %%
a=10
a

# %%
a=10
print(a) # print is used only see the answer

# %%
a=10
b=20
a
b

# %%
a=10
b=20
print(a)
print(b)

# %%
a=10
b=20
a,b

# %%
a=10        # work
b=20        # work
a,b=30      # fail
a,b=30,40   # work
a=50,60     # work

# %% [markdown]
# ### Variables

# %% [markdown]
# - Variables means will change the value also store the value

# %%
number=100
number=200
age=25
age=50

# %%
a=10
b=20
print(a,b)

# %%
number=100    # working
number

# %%
NUMBER=200   # working
NUMBER

# %%
NUMber=300    # working
NUMber

# %%
Number=400    # working
Number

# %%
number123=500  # working
number123

# %%
123number=600  # fail
123nummber

# %%
number@one=700   # fail
number@one

# %%
number@one=100 # f
number*one=200 # f
number&one=300 # f
number(one=400 # f
number$one=500 # f

# %%
number_one=10    # working
number_one

# %%
areaoftriangle=20   # working
areaoftriangle

# %%
area_of_triangle=30   # working
area_of_triangle

# %%
number one=50   ## fail
number one

# %%
n1=100  # n1 is defined
n2=n1   # n2 = 100
name=naresit

# %%
# black color = variables

# %%
nareshit=100
name=nareshit
name

# %%
hello    # string not defiened

# %%
"hello"    # working

# %%
calling

# %%
"calling"   # working

# %%
number=100 # w
NUMBER=200 # w
NUMBer=300 # w
number123=400 # w
number_one=500 # w
_=600 # w
number one=700 # f sy
number$one=800 # f sy
123number=900 # f sy
Virat=100
name=Virat # f===w logic
name='virat' # w

# %% [markdown]
# ### keywords or reserved words

# %%
False      await      else       import     pass
None       break      except     in         raise
async      elif       if         or         yield
match      case

# %% [markdown]
# ## Total Built function

# %%
abs()        dict()       help()       min()        setattr()
all()        dir()        hex()        next()       slice()
any()        divmod()     id()         object()     sorted()
ascii()      enumerate()  input()      oct()        staticmethod()
bin()        eval()       int()        open()       str()
bool()       exec()       isinstance() ord()        sum()
breakpoint() filter()     issubclass() pow()        super()
bytearray()  float()      iter()       print()      tuple()
bytes()      format()     len()        property()   type()
callable()   frozenset()  list()       range()      vars()
chr()        getattr()    locals()     repr()       zip()
classmethod() globals()   map()        reversed()   __import__()
compile()    hasattr()    max()        round()
complex()    hash()       memoryview() set()
delattr()    hasattr()    min()        set()

# %%
print=90
print

# %%
sum=50
sum

# %%
len=30
len

# %%
l=[1,2,3,4,5]
len(l)
# Out:
# 5

# %%
print()
len()
sum()
min()
max()

# %%
max(l)
# Out:
# 5

# %%
min(l)
# Out:
# 1

# %%
sum(l)
# Out:
# 15

# %%
# black means variable
# red means english
# green spl purpose

# %%
# It will work but not allowed
# in built functions are special use case
sum=100
len=500
max=700
min=800

# %%
# keywords are not works
if=700
