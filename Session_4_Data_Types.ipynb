# %% [markdown]
# ## What are Data Types in Python?
#
# **Data types batate hain ki variable ke andar kis type ka data store ho raha hai./n
# Matlab — number hai? text hai? true/false hai? list hai?**

# %% [markdown]
# **Total = 15 Builts in Data Types**

# %%
1 Numeric Types
Int
float
complex

2 Boolean Type
bool

3 Text Type
str

4 Sequence Types
list
tuple
range


6 Mapping Type
dict

7 Binary Types
bytes
bytearray
memoryview

8 None Type
NoneType

# %%
n1=10
type(n1)
# Out:
# int

# %% [markdown]
# - If we wants to know any types data or variables we will use
#     - **type inbuilt function**

# %% [markdown]
# - Float
#     - **Float means decimal value represtation**

# %%
n2=100.5
type(n2)
# Out:
# float

# %% [markdown]
# - **Exponential Data**

# %%
1e+1
# Out:
# 10.0

# %%
1e+2
# Out:
# 100.0

# %%
1e+3
# Out:
# 1000.0

# %%
1e+4
# Out:
# 10000.0

# %%
3e+1
# Out:
# 30.0

# %%
3e+2
# Out:
# 300.0

# %%
3e+3
# Out:
# 3000.0

# %%
3e+4
# Out:
# 30000.0

# %%
1e+1 # 1*10
2e+2 # 2*100
3e+3 # 3*1000
4e+4 # 4*10000

# %%
1e1
# Out:
# 10.0

# %%
1e2
# Out:
# 100.0

# %%
1e3
# Out:
# 1000.0

# %%
1e4
# Out:
# 10000.0

# %%
2e1
# Out:
# 20.0

# %%
2e2
# Out:
# 200.0

# %%
2e3
# Out:
# 2000.0

# %%
2e4
# Out:
# 20000.0

# %%
3e1
# Out:
# 30.0

# %%
3e2
# Out:
# 300.0

# %%
3e3
# Out:
# 3000.0

# %%
3e4
# Out:
# 30000.0

# %%
1e1 # 1*10
2e2 # 2*100
3e3 # 3*1000
4e4 # 4*10000

# %%
1e-1
# Out:
# 0.1

# %%
1e-2
# Out:
# 0.01

# %%
1e-3
# Out:
# 0.001

# %%
1e-4
# Out:
# 0.0001

# %%
2e-1
# Out:
# 0.2

# %%
2e-2
# Out:
# 0.02

# %%
2e-3
# Out:
# 0.002

# %%
2e-4
# Out:
# 0.0002

# %%
3e-1
# Out:
# 0.3

# %%
3e-2
# Out:
# 0.03

# %%
3e-3
# Out:
# 0.003

# %%
3e-4
# Out:
# 0.0003

# %%
4e-1
# Out:
# 0.4

# %%
1e-1  #  0.1
2e-1  #  0.2
3e-1  #  0.3
4e-1  #  0.4

# %%
1e+1 1e1
1e-1 1e/1

# %% [markdown]
# ## STRING

# %%
city='Hydrabad'
type(city)
# Out:
# str

# %%
name="nareshit"
type(name)
# Out:
# str

# %%
city
# Out:
# 'nareshit'

# %%
name
# Out:
# 'nareshit'

# %%
print(city)
# Out:
# nareshit

# %%
print(name)
# Out:
# nareshit

# %%
S1='hello'
len(S1)
# Out:
# 5

# %%
S2='hello          '
len(S2)
# Out:
# 15

# %%
S3=''
len(S3)
# Out:
# 0

# %%
S4='       '
len(S4)
# Out:
# 7

# %%
s1='hello'
s2='hell0     '
s1,s2
# Out:
# ('hello', 'hell0     ')

# %%
print(s1,s2)
# Out:
# hello hell0

# %%
print(s1)
print(s2)
# Out:
# hello
# hell0

# %%
print("I like your 'pyton'")
# Out:
# I like your 'pyton'

# %%
print('I like your "java"')
# Out:
# I like your "java"

# %% [markdown]
# - String can be Single quotes
#
# - String can be double quotes
#
# - Python be default use Single quotes only
#
# - If we want to highlight any world, then keep entire string in single quotes
#
# - nd highlighted world in double quotes vice versa.

# %% [markdown]
# ### DOC STRING

# %%
"Hello how are you
i am good"   ========> Fail
# Out:
#   File "<ipython-input-66-9850ca088377>", line 1
#     "Hello how are you
#                       ^
# SyntaxError: EOL while scanning string literal

# %%
'Hello how are you
i am good'  ========> Fail
# Out:
#   File "<ipython-input-68-b6d8c26744ab>", line 1
#     'Hello how are you
#                       ^
# SyntaxError: EOL while scanning string literal

# %%
s1=""""Hello are you
iam good"""
s1
# Out:
# '"Hello are you\niam good'

# %% [markdown]
# - But tripples quotes are recomended
#
# - Tripple quotes are used to communicate the information
#
# - If any user wrting tripple quotes
#
# - This is called Doc String

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Documents\\Data Science\\Python_Session'

# %% [markdown]
# ### Boolean Data Types

# %% [markdown]
# - True means 1 = On
# - False means 0 = OFF
#     - Something is not available means is Off

# %%
val1=True
type(val1)
# Out:
# bool

# %%
val2=False
type(val2)
# Out:
# bool

# %%
v1=True # Bool
s1="True" # string
true=10 # varaible
type(v1),type(s1),type(true)
# Out:
# (bool, str, int)

# %% [markdown]
# - We will coverd
#     - int
#     - str
#     - float
#     - bool
